# %%
import pandas as pd
base = pd.read_csv('census.csv')
base.head()
# Out:
#    age          workclass  final-weight   education  education-num  \
# 0   39          State-gov         77516   Bachelors             13
# 1   50   Self-emp-not-inc         83311   Bachelors             13
# 2   38            Private        215646     HS-grad              9
# 3   53            Private        234721        11th              7
# 4   28            Private        338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loos  hour-per-week  native-country  income
# 0          2174             0             40   United-States   <=50K
# 1             0             0             13   United-States   <=50K
# 2             0             0             40   United-States   <=50K
# 3             0             0             40   United-States   <=50K
# 4             0             0             40            Cuba   <=50K

# %%
base['income'].unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
def convert_classe(rotulo):
    if rotulo == ' >50K':
        return 1
    else:
        return 0

# %%
base['income'] = base['income'].apply(convert_classe)

# %%
base.head()
# Out:
#    age          workclass  final-weight   education  education-num  \
# 0   39          State-gov         77516   Bachelors             13
# 1   50   Self-emp-not-inc         83311   Bachelors             13
# 2   38            Private        215646     HS-grad              9
# 3   53            Private        234721        11th              7
# 4   28            Private        338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loos  hour-per-week  native-country  income
# 0          2174             0             40   United-States       0
# 1             0             0             13   United-States       0
# 2             0             0             40   United-States       0
# 3             0             0             40   United-States       0
# 4             0             0             40            Cuba       0

# %%
base['income'].unique()
# Out:
# array([0, 1])

# %%
X = base.drop('income', axis = 1)

# %%
X.head()
# Out:
#    age          workclass  final-weight   education  education-num  \
# 0   39          State-gov         77516   Bachelors             13
# 1   50   Self-emp-not-inc         83311   Bachelors             13
# 2   38            Private        215646     HS-grad              9
# 3   53            Private        234721        11th              7
# 4   28            Private        338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loos  hour-per-week  native-country
# 0          2174             0             40   United-States
# 1             0             0             13   United-States
# 2             0             0             40   United-States
# 3             0             0             40   United-States
# 4             0             0             40            Cuba

# %%
y = base['income']

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: income, dtype: int64

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
# %matplotlib inline
base.age.hist()

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From /Users/lucasyamamoto/opt/anaconda3/envs/codeby/lib/python3.6/site-packages/tensorflow_core/python/compat/v2_compat.py:65: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
idade = tf.feature_column.numeric_column('age')

# %%
idade_categorica = [tf.feature_column.bucketized_column(idade, boundaries=[20,30,40,50,60,70,80,90])]

# %%
print(idade_categorica)
# Out:
# [BucketizedColumn(source_column=NumericColumn(key='age', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(20, 30, 40, 50, 60, 70, 80, 90))]

# %%
X.columns
# Out:
# Index(['age', 'workclass', 'final-weight', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loos', 'hour-per-week', 'native-country'],
#       dtype='object')

# %%
nome_colunas_categoricas  = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 
                             'race', 'sex', 'native-country']

# %%
X['sex'].unique()
# Out:
# array([' Male', ' Female'], dtype=object)

# %%
X['workclass'].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
X['native-country'].unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' ?', ' Mexico',
#        ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
#        ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
#        ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
#        ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
#        ' Ireland', ' Hungary', ' Holand-Netherlands'], dtype=object)

# %%
colunas_categoricas = [tf.feature_column.categorical_column_with_vocabulary_list(key = c, vocabulary_list=X[c].unique()) for c in nome_colunas_categoricas]

# %%
print(colunas_categoricas[3])
# Out:
# VocabularyListCategoricalColumn(key='occupation', vocabulary_list=(' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners', ' Prof-specialty', ' Other-service', ' Sales', ' Craft-repair', ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct', ' Tech-support', ' ?', ' Protective-serv', ' Armed-Forces', ' Priv-house-serv'), dtype=tf.string, default_value=-1, num_oov_buckets=0)

# %%
nome_colunas_numericas = ['final-weight', 'education-num', 'capital-gain', 'capital-loos', 'hour-per-week']

# %%
colunas_numericas = [tf.feature_column.numeric_column(key = c) for c in nome_colunas_numericas]

# %%
print(colunas_numericas[0])
# Out:
# NumericColumn(key='final-weight', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)

# %%
colunas = idade_categorica + colunas_categoricas + colunas_numericas

# %%
from sklearn.model_selection import train_test_split
X_treinamento, X_teste, y_treinamento, y_teste = train_test_split(X, y, test_size = 0.3)

# %%
X_treinamento.shape
# Out:
# (22792, 14)

# %%
X_teste.shape
# Out:
# (9769, 14)

# %%
funcao_treinamento = tf.estimator.inputs.pandas_input_fn(x = X_treinamento, y = y_treinamento, batch_size=32, 
                                                         num_epochs=None, shuffle= True)

# %%
classificador = tf.estimator.LinearClassifier(feature_columns=colunas)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/g6/p8gwgl9130db7k9305wfz8340000gn/T/tmp3t0jj45i
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/g6/p8gwgl9130db7k9305wfz8340000gn/T/tmp3t0jj45i', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7ffb483bda58>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
classificador.train(input_fn=funcao_treinamento, steps=10000)
# Out:
# WARNING:tensorflow:From /Users/lucasyamamoto/opt/anaconda3/envs/codeby/lib/python3.6/site-packages/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From /Users/lucasyamamoto/opt/anaconda3/envs/codeby/lib/python3.6/site-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /Users/lucasyamamoto/opt/anaconda3/envs/codeby/lib/python3.6/site-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /Users/lucasyamamoto/opt/anaconda3/envs/codeby/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /Users/lucasyamamoto/opt/anaconda3/envs/codeby/lib/python3.6/site-packages/tensorflow_core/python/feature_column/feature_column_v2.py:518: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /Users/lucasyamamoto/opt/anaconda3/envs/codeby/lib/python3.6/site-packages/tensorflow_estimator/python/estimator/canned/linear.py:308: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From /Users/lucasyamamoto/opt/anaconda3/envs/codeby/lib/python3.6/site-packages/tensorflow_core/python/training/monitored_session.py:882: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Saving checkpoints for 0 into /var/folders/g6/p8gwgl9130db7k9305wfz8340000gn/T/tmp3t0jj45i/model.ckpt.
# INFO:tensorflow:loss = 22.18071, step = 1
# INFO:tensorflow:global_step/sec: 50.515
# INFO:tensorflow:loss = 30825.83, step = 101 (1.980 sec)
# INFO:tensorflow:global_step/sec: 175.583
# INFO:tensorflow:loss = 25291.303, step = 201 (0.571 sec)
# INFO:tensorflow:global_step/sec: 172.203
# INFO:tensorflow:loss = 32065.848, step = 301 (0.580 sec)
# INFO:tensorflow:global_step/sec: 167.833
# INFO:tensorflow:loss = 9050.627, step = 401 (0.596 sec)
# INFO:tensorflow:global_step/sec: 150.413
# INFO:tensorflow:loss = 6780.163, step = 501 (0.664 sec)
# INFO:tensorflow:global_step/sec: 174.157
# INFO:tensorflow:loss = 11848.563, step = 601 (0.579 sec)
# INFO:tensorflow:global_step/sec: 177.774
# INFO:tensorflow:loss = 3296.7224, step = 701 (0.558 sec)
# INFO:tensorflow:global_step/sec: 182.413
# INFO:tensorflow:loss = 17899.715, step = 801 (0.548 sec)
# INFO:tensorflow:global_step/sec: 179.848
# INFO:tensorflow:loss = 14102.08, step = 901 (0.565 sec)
# INFO:tensorflow:global_step/sec: 171.474
# INFO:tensorflow:loss = 7333.903, step = 1001 (0.575 sec)
# INFO:tensorflow:global_step/sec: 179.98
# INFO:tensorflow:loss = 3359.4429, step = 1101 (0.556 sec)
# INFO:tensorflow:global_step/sec: 181.627
# INFO:tensorflow:loss = 16442.447, step = 1201 (0.550 sec)
# INFO:tensorflow:global_step/sec: 180.114
# INFO:tensorflow:loss = 5075.9224, step = 1301 (0.556 sec)
# INFO:tensorflow:global_step/sec: 178.082
# INFO:tensorflow:loss = 16744.07, step = 1401 (0.561 sec)
# INFO:tensorflow:global_step/sec: 179.94
# INFO:tensorflow:loss = 6373.699, step = 1501 (0.556 sec)
# INFO:tensorflow:global_step/sec: 175.83
# INFO:tensorflow:loss = 4130.072, step = 1601 (0.569 sec)
# INFO:tensorflow:global_step/sec: 179.81
# INFO:tensorflow:loss = 7669.4287, step = 1701 (0.556 sec)
# INFO:tensorflow:global_step/sec: 183.796
# INFO:tensorflow:loss = 12376.087, step = 1801 (0.543 sec)
# INFO:tensorflow:global_step/sec: 177.881
# INFO:tensorflow:loss = 9636.4, step = 1901 (0.562 sec)
# INFO:tensorflow:global_step/sec: 167.707
# INFO:tensorflow:loss = 771.45764, step = 2001 (0.597 sec)
# INFO:tensorflow:global_step/sec: 101.13
# INFO:tensorflow:loss = 2494.6323, step = 2101 (0.988 sec)
# INFO:tensorflow:global_step/sec: 101.016
# INFO:tensorflow:loss = 1504.2272, step = 2201 (0.992 sec)
# INFO:tensorflow:global_step/sec: 84.7298
# INFO:tensorflow:loss = 8680.095, step = 2301 (1.188 sec)
# INFO:tensorflow:global_step/sec: 160.329
# INFO:tensorflow:loss = 1700.3235, step = 2401 (0.614 sec)
# INFO:tensorflow:global_step/sec: 163.75
# INFO:tensorflow:loss = 4067.709, step = 2501 (0.611 sec)
# INFO:tensorflow:global_step/sec: 163.541
# INFO:tensorflow:loss = 2789.6685, step = 2601 (0.612 sec)
# INFO:tensorflow:global_step/sec: 173.609
# INFO:tensorflow:loss = 1159.6316, step = 2701 (0.576 sec)
# INFO:tensorflow:global_step/sec: 173.557
# INFO:tensorflow:loss = 3917.5347, step = 2801 (0.576 sec)
# INFO:tensorflow:global_step/sec: 177.683
# INFO:tensorflow:loss = 9407.639, step = 2901 (0.563 sec)
# INFO:tensorflow:global_step/sec: 175.316
# INFO:tensorflow:loss = 1472.2715, step = 3001 (0.571 sec)
# INFO:tensorflow:global_step/sec: 154.012
# INFO:tensorflow:loss = 1588.8352, step = 3101 (0.651 sec)
# INFO:tensorflow:global_step/sec: 71.1957
# INFO:tensorflow:loss = 2343.9912, step = 3201 (1.409 sec)
# INFO:tensorflow:global_step/sec: 110.472
# INFO:tensorflow:loss = 3278.4116, step = 3301 (0.899 sec)
# INFO:tensorflow:global_step/sec: 175.5
# INFO:tensorflow:loss = 1059.7797, step = 3401 (0.570 sec)
# INFO:tensorflow:global_step/sec: 119.283
# INFO:tensorflow:loss = 7505.1626, step = 3501 (0.838 sec)
# INFO:tensorflow:global_step/sec: 99.1122
# INFO:tensorflow:loss = 2946.737, step = 3601 (1.010 sec)
# INFO:tensorflow:global_step/sec: 97.7607
# INFO:tensorflow:loss = 4012.2705, step = 3701 (1.026 sec)
# INFO:tensorflow:global_step/sec: 93.5821
# INFO:tensorflow:loss = 834.8182, step = 3801 (1.065 sec)
# INFO:tensorflow:global_step/sec: 134.538
# INFO:tensorflow:loss = 288.5932, step = 3901 (0.744 sec)
# INFO:tensorflow:global_step/sec: 107.844
# INFO:tensorflow:loss = 3261.9155, step = 4001 (0.929 sec)
# INFO:tensorflow:global_step/sec: 92.7971
# INFO:tensorflow:loss = 110.06934, step = 4101 (1.075 sec)
# INFO:tensorflow:global_step/sec: 96.4652
# INFO:tensorflow:loss = 7420.1006, step = 4201 (1.045 sec)
# INFO:tensorflow:global_step/sec: 134.973
# INFO:tensorflow:loss = 3636.2068, step = 4301 (0.732 sec)
# INFO:tensorflow:global_step/sec: 148.425
# INFO:tensorflow:loss = 3396.8823, step = 4401 (0.673 sec)
# INFO:tensorflow:global_step/sec: 140.204
# INFO:tensorflow:loss = 4577.8223, step = 4501 (0.714 sec)
# INFO:tensorflow:global_step/sec: 151.799
# INFO:tensorflow:loss = 1186.1622, step = 4601 (0.659 sec)
# INFO:tensorflow:global_step/sec: 163.932
# INFO:tensorflow:loss = 6531.9243, step = 4701 (0.609 sec)
# INFO:tensorflow:global_step/sec: 165.248
# INFO:tensorflow:loss = 832.12274, step = 4801 (0.609 sec)
# INFO:tensorflow:global_step/sec: 167.188
# INFO:tensorflow:loss = 4517.6587, step = 4901 (0.595 sec)
# INFO:tensorflow:global_step/sec: 153.728
# INFO:tensorflow:loss = 8369.709, step = 5001 (0.650 sec)
# INFO:tensorflow:global_step/sec: 154.552
# INFO:tensorflow:loss = 624.1238, step = 5101 (0.647 sec)
# INFO:tensorflow:global_step/sec: 157.124
# INFO:tensorflow:loss = 855.146, step = 5201 (0.637 sec)
# INFO:tensorflow:global_step/sec: 163.103
# INFO:tensorflow:loss = 4607.81, step = 5301 (0.615 sec)
# INFO:tensorflow:global_step/sec: 148.835
# INFO:tensorflow:loss = 2705.108, step = 5401 (0.670 sec)
# INFO:tensorflow:global_step/sec: 154.277
# INFO:tensorflow:loss = 2262.856, step = 5501 (0.647 sec)
# INFO:tensorflow:global_step/sec: 167.653
# INFO:tensorflow:loss = 3362.112, step = 5601 (0.596 sec)
# INFO:tensorflow:global_step/sec: 162.998
# INFO:tensorflow:loss = 4885.133, step = 5701 (0.613 sec)
# INFO:tensorflow:global_step/sec: 161.652
# INFO:tensorflow:loss = 619.1971, step = 5801 (0.619 sec)
# INFO:tensorflow:global_step/sec: 163.241
# INFO:tensorflow:loss = 1066.8021, step = 5901 (0.618 sec)
# INFO:tensorflow:global_step/sec: 165.585
# INFO:tensorflow:loss = 198.84755, step = 6001 (0.598 sec)
# INFO:tensorflow:global_step/sec: 171.465
# INFO:tensorflow:loss = 756.8097, step = 6101 (0.584 sec)
# INFO:tensorflow:global_step/sec: 162.302
# INFO:tensorflow:loss = 530.76825, step = 6201 (0.616 sec)
# INFO:tensorflow:global_step/sec: 169.401
# INFO:tensorflow:loss = 819.2167, step = 6301 (0.591 sec)
# INFO:tensorflow:global_step/sec: 169.6
# INFO:tensorflow:loss = 177.18506, step = 6401 (0.589 sec)
# INFO:tensorflow:global_step/sec: 164.245
# INFO:tensorflow:loss = 416.21924, step = 6501 (0.609 sec)
# INFO:tensorflow:global_step/sec: 165.211
# INFO:tensorflow:loss = 709.7664, step = 6601 (0.605 sec)
# INFO:tensorflow:global_step/sec: 156.924
# INFO:tensorflow:loss = 1070.4236, step = 6701 (0.637 sec)
# INFO:tensorflow:global_step/sec: 151.778
# INFO:tensorflow:loss = 312.48694, step = 6801 (0.662 sec)
# INFO:tensorflow:global_step/sec: 162.669
# INFO:tensorflow:loss = 427.96558, step = 6901 (0.612 sec)
# INFO:tensorflow:global_step/sec: 150.003
# INFO:tensorflow:loss = 7098.6523, step = 7001 (0.666 sec)
# INFO:tensorflow:global_step/sec: 157.665
# INFO:tensorflow:loss = 3893.8508, step = 7101 (0.635 sec)
# INFO:tensorflow:global_step/sec: 156.883
# INFO:tensorflow:loss = 2812.3657, step = 7201 (0.638 sec)
# INFO:tensorflow:global_step/sec: 159.41
# INFO:tensorflow:loss = 341.7159, step = 7301 (0.626 sec)
# INFO:tensorflow:global_step/sec: 165.895
# INFO:tensorflow:loss = 904.9239, step = 7401 (0.606 sec)
# INFO:tensorflow:global_step/sec: 163.124
# INFO:tensorflow:loss = 632.1063, step = 7501 (0.610 sec)
# INFO:tensorflow:global_step/sec: 155.34
# INFO:tensorflow:loss = 4393.9556, step = 7601 (0.643 sec)
# INFO:tensorflow:global_step/sec: 138.055
# INFO:tensorflow:loss = 2277.3865, step = 7701 (0.725 sec)
# INFO:tensorflow:global_step/sec: 159.853
# INFO:tensorflow:loss = 1299.2068, step = 7801 (0.626 sec)
# INFO:tensorflow:global_step/sec: 168.532
# INFO:tensorflow:loss = 546.2079, step = 7901 (0.597 sec)
# INFO:tensorflow:global_step/sec: 163.995
# INFO:tensorflow:loss = 9145.686, step = 8001 (0.606 sec)
# INFO:tensorflow:global_step/sec: 171.423
# INFO:tensorflow:loss = 762.32153, step = 8101 (0.583 sec)
# INFO:tensorflow:global_step/sec: 175.963
# INFO:tensorflow:loss = 3484.8765, step = 8201 (0.569 sec)
# INFO:tensorflow:global_step/sec: 167.78
# INFO:tensorflow:loss = 270.93686, step = 8301 (0.596 sec)
# INFO:tensorflow:global_step/sec: 159.841
# INFO:tensorflow:loss = 2072.837, step = 8401 (0.626 sec)
# INFO:tensorflow:global_step/sec: 155.272
# INFO:tensorflow:loss = 1473.6382, step = 8501 (0.643 sec)
# INFO:tensorflow:global_step/sec: 159.36
# INFO:tensorflow:loss = 2285.7659, step = 8601 (0.627 sec)
# INFO:tensorflow:global_step/sec: 155.892
# INFO:tensorflow:loss = 532.0271, step = 8701 (0.641 sec)
# INFO:tensorflow:global_step/sec: 155.928
# INFO:tensorflow:loss = 2880.336, step = 8801 (0.642 sec)
# INFO:tensorflow:global_step/sec: 159.662
# INFO:tensorflow:loss = 4908.363, step = 8901 (0.626 sec)
# INFO:tensorflow:global_step/sec: 152.251
# INFO:tensorflow:loss = 3815.079, step = 9001 (0.657 sec)
# INFO:tensorflow:global_step/sec: 152.075
# INFO:tensorflow:loss = 425.89264, step = 9101 (0.658 sec)
# INFO:tensorflow:global_step/sec: 165.479
# INFO:tensorflow:loss = 276.45007, step = 9201 (0.604 sec)
# INFO:tensorflow:global_step/sec: 166.15
# INFO:tensorflow:loss = 773.96924, step = 9301 (0.603 sec)
# INFO:tensorflow:global_step/sec: 158.368
# INFO:tensorflow:loss = 3381.1577, step = 9401 (0.630 sec)
# INFO:tensorflow:global_step/sec: 158.919
# INFO:tensorflow:loss = 3510.5977, step = 9501 (0.629 sec)
# INFO:tensorflow:global_step/sec: 164.786
# INFO:tensorflow:loss = 4827.365, step = 9601 (0.608 sec)
# INFO:tensorflow:global_step/sec: 160.881
# INFO:tensorflow:loss = 835.3478, step = 9701 (0.620 sec)
# INFO:tensorflow:global_step/sec: 163.799
# INFO:tensorflow:loss = 2753.9927, step = 9801 (0.613 sec)
# INFO:tensorflow:global_step/sec: 147.279
# INFO:tensorflow:loss = 1642.6871, step = 9901 (0.678 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into /var/folders/g6/p8gwgl9130db7k9305wfz8340000gn/T/tmp3t0jj45i/model.ckpt.
# INFO:tensorflow:Loss for final step: 2318.811.

# %%
funcao_previsao = tf.estimator.inputs.pandas_input_fn(x = X_teste, batch_size = 32, shuffle = False)

# %%
previsoes = classificador.predict(input_fn=funcao_previsao)

# %%
list(previsoes)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/g6/p8gwgl9130db7k9305wfz8340000gn/T/tmp3t0jj45i/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [{'logits': array([-430.83237], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-369.42252], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-325.40775], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-365.14923], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([297.3359], dtype=float32),
#   'logistic': array([1.], dtype=float32),
#   'probabilities': array([0., 1.], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-206.22491], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-407.11386], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-8.170367], dtype=float32),
#   'logistic': array([0.00028285], dtype=float32),
#   'probabilities': array([9.9971718e-01, 2.8283405e-04], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-389.52557], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-86.93904], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1.0000000e+00, 1.7492598e-38], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-561.405], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-117.95473], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-797.7646], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-138.93906], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-591.9135], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-685.4669], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-262.8571], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-234.62027], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-483.67465], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-531.1188], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-358.4276], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-479.07983], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-82.27515], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1.0000000e+00, 1.8550598e-36], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-161.72662], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-258.37268], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-666.9666], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-309.28006], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-494.1437], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-68.69148], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1.0000000e+00, 1.4711882e-30], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-435.53458], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-60.50478], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1.0000000e+00, 5.2857667e-27], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-515.0793], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-404.7682], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-348.8238], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-313.75455], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-75.956894], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1.0000000e+00, 1.0288219e-33], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-303.9026], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-472.1376], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-572.83136], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-246.28693], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-478.08408], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-306.50885], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-469.04962], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-584.09454], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-533.842], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-374.1155], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-354.24197], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-92.7225], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-196.97829], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([169.17401], dtype=float32),
#   'logistic': array([1.], dtype=float32),
#   'probabilities': array([0., 1.], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-64.404465], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1.0000000e+00, 1.0702775e-28], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([11.422148], dtype=float32),
#   'logistic': array([0.99998903], dtype=float32),
#   'probabilities': array([1.0950136e-05, 9.9998903e-01], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([144.64864], dtype=float32),
#   'logistic': array([1.], dtype=float32),
#   'probabilities': array([0., 1.], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-464.88956], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-646.6617], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-687.0245], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-563.64014], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-374.05344], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-137.4235], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-653.1357], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-424.96408], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-72.05475], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1.000000e+00, 5.093548e-32], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-17.456495], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1.0000000e+00, 2.6226504e-08], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-763.21124], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-438.83755], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-404.58054], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-487.2513], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-274.9299], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-247.16644], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-169.7074], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-336.12122], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-295.87885], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-367.10736], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-413.91666], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-364.5161], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-816.5939], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-317.75204], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-138.3245], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-500.7643], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-631.8288], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-168.60571], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-528.0068], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-362.2688], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-181.71547], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-337.11725], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-135.55728], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-317.55756], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-259.73123], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-67.19635], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1.000000e+00, 6.561393e-30], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-161.12614], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-278.85574], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-441.3292], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-73.46652], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1.0000000e+00, 1.2413519e-32], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-93.86731], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-476.97797], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-297.33322], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-60.615192], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1.0000000e+00, 4.7332182e-27], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-446.47925], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-10.950778], dtype=float32),
#   'logistic': array([1.7553568e-05], dtype=float32),
#   'probabilities': array([9.9998248e-01, 1.7544051e-05], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([305.60785], dtype=float32),
#   'logistic': array([1.], dtype=float32),
#   'probabilities': array([0., 1.], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-627.0431], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-143.77216], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-536.45416], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-396.52197], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-373.1981], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-531.58844], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-323.4503], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-340.56165], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-347.01834], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-576.848], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-362.66104], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-81.729744], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1.0000000e+00, 3.2005402e-36], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-700.87836], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-512.90643], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-197.51562], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-654.9968], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-317.64667], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-210.87718], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-288.36688], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-290.76285], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-475.56082], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-363.80994], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-170.81981], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-132.49591], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-289.5056], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-99.72104], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-92.40811], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-328.18005], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-109.58672], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-187.70268], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-378.23807], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-196.95229], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-310.7693], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-242.60222], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-278.37888], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-191.6642], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-503.28973], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-276.16827], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-148.53145], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-351.0795], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-258.68744], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-271.78354], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-433.93304], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-146.43513], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-148.99303], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-470.83072], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-761.2955], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-477.6989], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-443.72952], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-61.582138], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1.0000000e+00, 1.7997711e-27], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-393.77988], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-485.72543], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-526.0779], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
# ...
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-173.62463], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-426.63278], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-99.051285], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-418.5376], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-549.4327], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-356.21896], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([41.251408], dtype=float32),
#   'logistic': array([1.], dtype=float32),
#   'probabilities': array([1.2154618e-18, 1.0000000e+00], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-378.2687], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-304.0518], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-451.18594], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-185.10661], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-756.26807], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-265.25967], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-19.485752], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1.0000000e+00, 3.4470324e-09], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-400.8023], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-472.9584], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-127.09], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-255.2079], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-410.08432], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-554.81274], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-19.117798], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1.00000e+00, 4.98019e-09], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([91.30666], dtype=float32),
#   'logistic': array([1.], dtype=float32),
#   'probabilities': array([0., 1.], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-684.50024], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-693.19666], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-217.59265], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-216.14926], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-278.30905], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-300.01178], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-311.1586], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-416.94055], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-187.4381], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([160.26938], dtype=float32),
#   'logistic': array([1.], dtype=float32),
#   'probabilities': array([0., 1.], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-676.0441], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-454.7377], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-155.37184], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-206.20374], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-64.057175], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1.0000000e+00, 1.5146859e-28], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-13.549445], dtype=float32),
#   'logistic': array([1.2516975e-06], dtype=float32),
#   'probabilities': array([9.9999869e-01, 1.3048187e-06], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-192.57095], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-325.41287], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-151.04411], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-584.636], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-324.7986], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-422.94766], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-548.5655], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-375.16513], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-177.8958], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([278.66174], dtype=float32),
#   'logistic': array([1.], dtype=float32),
#   'probabilities': array([0., 1.], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-80.35078], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1.0000000e+00, 1.2708701e-35], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-290.48663], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-592.17346], dtype=float32),
#   'logistic': array([0.], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  ...]

# %%
previsoes_final = []
for p in classificador.predict(input_fn=funcao_previsao):
    previsoes_final.append(p['class_ids'])
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/g6/p8gwgl9130db7k9305wfz8340000gn/T/tmp3t0jj45i/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
previsoes_final
# Out:
# [array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  ...]

# %%
from sklearn.metrics import accuracy_score
taxa_acerto = accuracy_score(y_teste, previsoes_final)
taxa_acerto
# Out:
# 0.7884123247005835
